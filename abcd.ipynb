# %%
a=1
b=2

c = a+b
print(c)
# Out:
# 3

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
github_username = 'adashis19'
github_password = 'AD#edge1991'
github_repo_name = 'abcd'
user_email = 'adashis@gmail.com'

# %%
# !git remote add origin https://{github_username}:{github_password}@github.com/{github_username}/{github_repo_name}.git}
# !git remote -v
# Out:
# error: remote origin already exists.
# origin	https://{github_username}:{github_password}@github.com/{{github_username}}/{{github_repo_name}.git} (fetch)
# origin	https://{github_username}:{github_password}@github.com/{{github_username}}/{{github_repo_name}.git} (push)

# %%
# !git remote add origin https://adashis19:AD%23edge1991@github.com/adashis19/abcd.git
# !git remote -v
# Out:
# error: remote origin already exists.
# origin	https://{github_username}:{github_password}@github.com/{{github_username}}/{{github_repo_name}.git} (fetch)
# origin	https://{github_username}:{github_password}@github.com/{{github_username}}/{{github_repo_name}.git} (push)

# %%
# !git remote set-url origin https://adashis19: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github.com/adashis19/abcd.git

# %%
# !git config --global user.email '{user_email}'
# !git config --global user.name '{user_name}'

# %%
# !git remote -v
# Out:
# origin	https://github.com/adashis19/abcd.git (fetch)
# origin	https://github.com/adashis19/abcd.git (push)

# %%
# !git add abcd.ipynb

# %%
# !git commit -m 'First'
# Out:
# [master 79482a2] First
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
